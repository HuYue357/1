# %%
# -*- coding: utf-8 -*-
"""
Windows 下使用：
1) 把这个脚本文件放到和 *.jsonl 相同的目录；
2) 在该目录执行:  python add_ctx_windows.py
3) 新文件会输出到 ./with_ctx/ 目录
"""

import os
import re
import json
from pathlib import Path

# ===== 复刻 Scala 里的 allProfiles 顺序（保持完全一致） =====
def make_all_profiles():
    bools = ["true", "false"]
    brThr = ["-1", "64MB", "128MB", "256MB"]
    shuf  = ["64", "128", "200", "400", "800"]
    profiles = []
    for aqe in bools:
        for cbo in bools:
            for smj in bools:
                for bt in brThr:
                    for sp in shuf:
                        kv = {
                            "spark.sql.adaptive.enabled": aqe,
                            "spark.sql.cbo.enabled": cbo,
                            "spark.sql.cbo.joinReorder.enabled": cbo,
                            "spark.sql.join.preferSortMergeJoin": smj,
                            "spark.sql.autoBroadcastJoinThreshold": bt,
                            "spark.sql.shuffle.partitions": sp,
                        }
                        profiles.append((kv))
    return profiles[:50]

ALL_PROFILES = make_all_profiles()
Q = 103  # TPCDS v2.4 查询条数（根据你的环境保持一致）

def idx_to_pq(N: int, Q: int):
    """根据全局编号 N（1-based 文件名）还原到 (pIdx, qIdx)，也都是 1-based。"""
    pIdx = ((N - 1) // Q) + 1
    qIdx = ((N - 1) %  Q) + 1
    return pIdx, qIdx

def as_ctx_dict(kv: dict) -> dict:
    """保持与 Scala 侧一致的字符串值；训练侧再做 0/1、log1p 等数值化。"""
    return {
        "spark.sql.adaptive.enabled": kv["spark.sql.adaptive.enabled"],
        "spark.sql.cbo.enabled": kv["spark.sql.cbo.enabled"],
        "spark.sql.join.preferSortMergeJoin": kv["spark.sql.join.preferSortMergeJoin"],
        "spark.sql.autoBroadcastJoinThreshold": kv["spark.sql.autoBroadcastJoinThreshold"],
        "spark.sql.shuffle.partitions": kv["spark.sql.shuffle.partitions"],
    }

def main():
    # 使用当前工作目录作为 jsonl 目录
    src_dir = Path(os.getcwd())
    dst_dir = src_dir / "with_ctx"
    dst_dir.mkdir(parents=True, exist_ok=True)

    num_re = re.compile(r"^(\d+)\.jsonl$", re.IGNORECASE)

    files = []
    for p in src_dir.iterdir():
        if p.is_file():
            m = num_re.match(p.name)
            if m:
                files.append((int(m.group(1)), p))
    files.sort(key=lambda t: t[0])  # 按编号升序

    print(f"[info] 发现 {len(files)} 个 jsonl 文件（形如 N.jsonl）")

    for N, fp in files:
        pIdx, qIdx = idx_to_pq(N, Q)
        if not (1 <= pIdx <= len(ALL_PROFILES)):
            print(f"[warn] N={N} -> pIdx={pIdx} 超出 profiles 范围（len={len(ALL_PROFILES)}），跳过该文件")
            continue

        kv = ALL_PROFILES[pIdx - 1]
        out_fp = dst_dir / fp.name

        with open(fp, "r", encoding="utf-8", newline="") as fin, \
             open(out_fp, "w", encoding="utf-8", newline="") as fout:
            for line in fin:
                line = line.strip()
                if not line:
                    continue
                obj = json.loads(line)
                if "ctx" not in obj:
                    obj["ctx"] = as_ctx_dict(kv)
                fout.write(json.dumps(obj, ensure_ascii=False) + "\n")

        print(f"[ok] {fp.name} -> 输出到 {out_fp}")

    print(f"\n[done] 所有文件已处理。新文件在 {dst_dir}")

if __name__ == "__main__":
    main()
# Out:
# [info] 发现 244 个 jsonl 文件（形如 N.jsonl）
# [ok] 1.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx
jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\183.jsonl
# [ok] 185.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\185.jsonl
# [ok] 186.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\186.jsonl
# [ok] 187.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\187.jsonl
# [ok] 188.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\188.jsonl
# [ok] 189.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\189.jsonl
# [ok] 190.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\190.jsonl
# [ok] 191.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\191.jsonl
# [ok] 193.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\193.jsonl
# [ok] 194.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\194.jsonl
# [ok] 195.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\195.jsonl
# [ok] 197.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\197.jsonl
# [ok] 199.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\199.jsonl
# [ok] 200.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\200.jsonl
# [ok] 205.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\205.jsonl
# [ok] 206.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\206.jsonl
# [ok] 209.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\209.jsonl
# [ok] 211.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\211.jsonl
# [ok] 212.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\212.jsonl
# [ok] 213.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\213.jsonl
# [ok] 214.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\214.jsonl
# [ok] 215.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\215.jsonl
# [ok] 216.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\216.jsonl
# [ok] 218.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\218.jsonl
# [ok] 219.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\219.jsonl
# [ok] 220.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\220.jsonl
# [ok] 221.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\221.jsonl
# [ok] 222.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\222.jsonl
# [ok] 223.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\223.jsonl
# [ok] 224.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\224.jsonl
# [ok] 226.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\226.jsonl
# [ok] 227.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\227.jsonl
# [ok] 228.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\228.jsonl
# [ok] 229.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\229.jsonl
# [ok] 230.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\230.jsonl
# [ok] 231.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\231.jsonl
# [ok] 232.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\232.jsonl
# [ok] 233.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\233.jsonl
# [ok] 236.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\236.jsonl
# [ok] 237.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\237.jsonl
# [ok] 238.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\238.jsonl
# [ok] 240.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\240.jsonl
# [ok] 241.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\241.jsonl
# [ok] 242.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\242.jsonl
# [ok] 243.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\243.jsonl
# [ok] 244.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\244.jsonl
# [ok] 245.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\245.jsonl
# [ok] 246.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\246.jsonl
# [ok] 247.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\247.jsonl
# [ok] 248.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\248.jsonl
# [ok] 249.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\249.jsonl
# [ok] 250.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\250.jsonl
# [ok] 251.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\251.jsonl
# [ok] 252.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\252.jsonl
# [ok] 254.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\254.jsonl
# [ok] 255.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\255.jsonl
# [ok] 257.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\257.jsonl
# [ok] 258.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\258.jsonl
# [ok] 259.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\259.jsonl
# [ok] 260.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\260.jsonl
# [ok] 261.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\261.jsonl
# [ok] 262.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\262.jsonl
# [ok] 263.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\263.jsonl
# [ok] 264.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\264.jsonl
# [ok] 265.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\265.jsonl
# [ok] 266.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\266.jsonl
# [ok] 267.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\267.jsonl
# [ok] 268.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\268.jsonl
# [ok] 269.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\269.jsonl
# [ok] 270.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\270.jsonl
# [ok] 272.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\272.jsonl
# [ok] 273.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\273.jsonl
# [ok] 275.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\275.jsonl
# [ok] 276.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\276.jsonl
# [ok] 277.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\277.jsonl
# [ok] 278.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\278.jsonl
# [ok] 279.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\279.jsonl
# [ok] 280.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\280.jsonl
# [ok] 281.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\281.jsonl
# [ok] 282.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\282.jsonl
# [ok] 283.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\283.jsonl
# [ok] 284.jsonl -> 输出到 C:\Users\huyue\Desktop\Result\train\with_ctx\284.jsonl
#
# [done] 所有文件已处理。新文件在 C:\Users\huyue\Desktop\Result\train\with_ctx
